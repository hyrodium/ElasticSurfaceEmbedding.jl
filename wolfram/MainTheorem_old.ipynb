# %% [markdown]
# # Main Theorem of Elastic Surface Embedding
# In the general case
#
# ## Geometry of the reference state

# %%
(* Riemannian metric *)
g₍₀₎₁₁[u¹_, u²_] = 1 - 2 𝜅₍₀₎[u¹] u² + (𝜅₍₀₎[u¹]^2 - 𝐾₍₀₎[u¹]) u²^2 + O[u²]^3;
g₍₀₎₁₂[u¹_, u²_] = 0;
g₍₀₎₂₁[u¹_, u²_] = 0;
g₍₀₎₂₂[u¹_, u²_] = 1;
g₍₀₎[u¹_, u²_] = {{g₍₀₎₁₁[u¹, u²],g₍₀₎₁₂[u¹, u²]},{g₍₀₎₂₁[u¹, u²],g₍₀₎₂₂[u¹, u²]}};

(* Normalize *)
g₍₀₎⁽⁰⁾₁₁[u¹_, u²_] = 1;
g₍₀₎⁽⁰⁾₁₂[u¹_, u²_] = 0;
g₍₀₎⁽⁰⁾₂₁[u¹_, u²_] = 0;
g₍₀₎⁽⁰⁾₂₂[u¹_, u²_] = 1;
(* g₍₀₎⁽⁰⁾[u¹_, u²_] = {{g₍₀₎⁽⁰⁾₁₁[u¹, u²],g₍₀₎⁽⁰⁾₁₂[u¹, u²]},{g₍₀₎⁽⁰⁾₂₁[u¹, u²],g₍₀₎⁽⁰⁾₂₂[u¹, u²]}}; *)

(* Volume form *)
𝝊₍₀₎[u¹_, u²_] = Sqrt[Det[g₍₀₎[u¹, u²]]];

(* Breadth-parametrized *)
g₍₀₎₁₁ᵦ = (Normal[g₍₀₎₁₁[u¹, u²]] /. {u¹->s, u²->r B[s] β}) + O[β]^3;
g₍₀₎₁₂ᵦ = 0;
g₍₀₎₂₁ᵦ = 0;
g₍₀₎₂₂ᵦ = 1;
g₍₀₎⁽⁰⁾₁₁ᵦ = 1;
g₍₀₎⁽⁰⁾₁₂ᵦ = 0;
g₍₀₎⁽⁰⁾₂₁ᵦ = 0;
g₍₀₎⁽⁰⁾₂₂ᵦ = 1;
𝝊₍₀₎ᵦ = (Normal[𝝊₍₀₎[u¹, u²]] /. {u¹->s, u²->r B[s] β}) + O[β]^3;

# %% [markdown]
# ## Geometry of the current state

# %%
(* Embedding M₍₀₎ to 2-dim Euclidean space *)
𝒑₍ₜ₎[u¹_, u²_, β_] = 𝒄₍ₜ₎[u¹, β] + 𝜉[u¹, u², β]𝒆₁[u¹, β] + 𝜂[u¹, u², β]𝒆₂[u¹, β];
Derivative[1,0][𝒄₍ₜ₎][u¹_, β_] = s₍ₜ₎[u¹, β]𝒆₁[u¹, β];
Derivative[1,0][𝒆₁][u¹_, β_] = 𝜅₍ₜ₎[u¹, β]𝒆₂[u¹, β];
Derivative[1,0][𝒆₂][u¹_, β_] = -𝜅₍ₜ₎[u¹, β]𝒆₁[u¹, β];
𝜉[u¹_, 0, β_] = 0;
𝜂[u¹_, 0, β_] = 0;
Derivative[i_,0,k_][𝜉][u¹_, 0, β_] = 0;
Derivative[i_,0,k_][𝜂][u¹_, 0, β_] = 0;

(* Tangent vector *)
𝒑₍ₜ₎₁[u¹_, u²_, β_] = D[𝒑₍ₜ₎[u¹, u², β], u¹];
𝒑₍ₜ₎₂[u¹_, u²_, β_] = D[𝒑₍ₜ₎[u¹, u², β], u²];

(* Riemannian metric *)
tmp1[u¹_, u²_, β_] = 𝒑₍ₜ₎₁[u¹, u², β]/.{𝒆₁[u¹, β] -> {1,0}, 𝒆₂[u¹, β] -> {0,1}};
tmp2[u¹_, u²_, β_] = 𝒑₍ₜ₎₂[u¹, u², β]/.{𝒆₁[u¹, β] -> {1,0}, 𝒆₂[u¹, β] -> {0,1}};
g₍ₜ₎₁₁[u¹_, u²_, β_] = tmp1[u¹, u², β].tmp1[u¹, u², β];
g₍ₜ₎₁₂[u¹_, u²_, β_] = tmp1[u¹, u², β].tmp2[u¹, u², β];
g₍ₜ₎₂₁[u¹_, u²_, β_] = tmp2[u¹, u², β].tmp1[u¹, u², β];
g₍ₜ₎₂₂[u¹_, u²_, β_] = tmp2[u¹, u², β].tmp2[u¹, u², β];
g₍ₜ₎[u¹_, u²_, β_] = {{g₍ₜ₎₁₁[u¹, u², β],g₍ₜ₎₁₂[u¹, u², β]},{g₍ₜ₎₂₁[u¹, u², β],g₍ₜ₎₂₂[u¹, u², β]}};

(* Normalize *)
g₍ₜ₎⁽⁰⁾₁₁[u¹_, u²_, β_] = g₍ₜ₎₁₁[u¹, u², β] / g₍₀₎₁₁[u¹, u²];
g₍ₜ₎⁽⁰⁾₁₂[u¹_, u²_, β_] = g₍ₜ₎₁₂[u¹, u², β] / Sqrt[g₍₀₎₁₁[u¹, u²]];
g₍ₜ₎⁽⁰⁾₂₁[u¹_, u²_, β_] = g₍ₜ₎₂₁[u¹, u², β] / Sqrt[g₍₀₎₁₁[u¹, u²]];
g₍ₜ₎⁽⁰⁾₂₂[u¹_, u²_, β_] = g₍ₜ₎₂₂[u¹, u², β];
g₍ₜ₎⁽⁰⁾[u¹_, u²_, β_] = {{g₍ₜ₎⁽⁰⁾₁₁[u¹, u², β],g₍ₜ₎⁽⁰⁾₁₂[u¹, u², β]},{g₍ₜ₎⁽⁰⁾₂₁[u¹, u², β],g₍ₜ₎⁽⁰⁾₂₂[u¹, u², β]}};

(* Breadth-parametrized *)
g₍ₜ₎⁽⁰⁾₁₁ᵦ = (Normal[g₍ₜ₎⁽⁰⁾₁₁[u¹, u², β]] /. {u¹->s, u²->r B[s] β}) + O[β]^3;
g₍ₜ₎⁽⁰⁾₁₂ᵦ = (Normal[g₍ₜ₎⁽⁰⁾₁₂[u¹, u², β]] /. {u¹->s, u²->r B[s] β}) + O[β]^3;
g₍ₜ₎⁽⁰⁾₂₁ᵦ = (Normal[g₍ₜ₎⁽⁰⁾₂₁[u¹, u², β]] /. {u¹->s, u²->r B[s] β}) + O[β]^3;
g₍ₜ₎⁽⁰⁾₂₂ᵦ = (Normal[g₍ₜ₎⁽⁰⁾₂₂[u¹, u², β]] /. {u¹->s, u²->r B[s] β}) + O[β]^3;

# %% [markdown]
# ## Strain tensor, strain energy density

# %%
(* Green's strain tensor *)
E⁽⁰⁾₁₁ᵦ = (g₍ₜ₎⁽⁰⁾₁₁ᵦ - g₍₀₎⁽⁰⁾₁₁ᵦ)/2;
E⁽⁰⁾₁₂ᵦ = (g₍ₜ₎⁽⁰⁾₁₂ᵦ - g₍₀₎⁽⁰⁾₁₂ᵦ)/2;
E⁽⁰⁾₂₁ᵦ = (g₍ₜ₎⁽⁰⁾₂₁ᵦ - g₍₀₎⁽⁰⁾₂₁ᵦ)/2;
E⁽⁰⁾₂₂ᵦ = (g₍ₜ₎⁽⁰⁾₂₂ᵦ - g₍₀₎⁽⁰⁾₂₂ᵦ)/2;
E⁽⁰⁾ᵦ = {{E⁽⁰⁾₁₁ᵦ,E⁽⁰⁾₁₂ᵦ},{E⁽⁰⁾₂₁ᵦ,E⁽⁰⁾₂₂ᵦ}} // Simplify;

(* Lamé constant *)
d = 2;
𝜆 = 𝜈*Y/((1+𝜈)(1-(d-1)𝜈));
𝜇 = Y/(2(1+𝜈));
𝛿 = KroneckerDelta;
C⁽⁰⁾ = Table[𝜆 𝛿[i,j] 𝛿[k,l] + 𝜇(𝛿[i,k] 𝛿[j,l] + 𝛿[i,l] 𝛿[j,k]), {i,1,d}, {j,1,d}, {k,1,d}, {l,1,d}];

(* Strain energy density *)
𝒲[E⁽⁰⁾ᵦ_] := β*B[s]*Integrate[(1/2)*Sum[C⁽⁰⁾[[i,j,k,l]]*E⁽⁰⁾ᵦ[[i,j]]*E⁽⁰⁾ᵦ[[k,l]], {i,1,d}, {j,1,d}, {k,1,d}, {l,1,d}] 𝝊₍₀₎ᵦ, {r,-1,1}];

# %%
(* Coefficient *)
a[m_,E⁽⁰⁾ᵦ_] := Block[
    {
        ee,
        integrand,
        normal,
        landau,
        W
    },
    integrand = (1/2)*Sum[C⁽⁰⁾[[i,j,k,l]]*E⁽⁰⁾ᵦ[[i,j]]*E⁽⁰⁾ᵦ[[k,l]], {i,1,d}, {j,1,d}, {k,1,d}, {l,1,d}] 𝝊₍₀₎ᵦ // Simplify;
    normal = Normal[integrand];
    landau = integrand - normal;
    W = β*B[s]*(Integrate[normal, {r,-1,1}]+landau);
    Normal[D[W,{β,m}]] /. {β->0}
]

(* Symbol definition for LaTeX code generation *)
xi = Table[
    "\\text{$"<>ToString[TeXForm[𝜉]]<>"$"<>ToString[i]<>ToString[j]<>ToString[k]<>"}" -> "{\\xi^{("<>ToString[i]<>","<>ToString[j]<>","<>ToString[k]<>")}}",
    {i,0,5},{j,0,5},{k,0,5}
];
eta = Table[
    "\\text{$"<>ToString[TeXForm[𝜂]]<>"$"<>ToString[i]<>ToString[j]<>ToString[k]<>"}" -> "{\\eta^{("<>ToString[i]<>","<>ToString[j]<>","<>ToString[k]<>")}}",
    {i,0,5},{j,0,5},{k,0,5}
];
kappat = Table[
    "\\text{$"<>ToString[TeXForm[𝜅]]<>"$"<>ToString[i]<>ToString[j]<>"}" -> "{\\kappa_{[t]}^{("<>ToString[i]<>","<>ToString[j]<>")}}",
    {i,0,5},{j,0,5}
];
kappa0 = {ToString[TeXForm[𝜅₍₀₎]] -> "\\kappa_{[0]]}"};
gaussian0 = {ToString[TeXForm[𝐾₍₀₎]] -> "K_{[0]]}"};
velocity = Table[
    "\\text{s"<>ToString[i]<>ToString[j]<>"}" -> "{s_{[t]}^{("<>ToString[i]<>","<>ToString[j]<>")}}",
    {i,0,5},{j,0,5}
];
nu = {ToString[TeXForm[𝜈]] -> "{\\nu}"};
orig = {
    ToString[TeXForm[𝒆₁[u¹, β]]] -> "\\bm{e}_{1}",
    ToString[TeXForm[𝒆₂[u¹, β]]] -> "\\bm{e}_{2}",
    ToString[TeXForm[𝜉[u¹, u², β]]] -> "\\xi",
    ToString[TeXForm[𝜂[u¹, u², β]]] -> "\\eta",
    ToString[TeXForm[D[𝜉[u¹, u², β],u¹]]] -> "\\xi_1",
    ToString[TeXForm[D[𝜂[u¹, u², β],u¹]]] -> "\\eta_1",
    ToString[TeXForm[D[𝜉[u¹, u², β],u²]]] -> "\\xi_2",
    ToString[TeXForm[D[𝜂[u¹, u², β],u²]]] -> "\\eta_2",
    ToString[TeXForm[𝜅₍ₜ₎[u¹, β]]] -> "\\kappa_{[t]}",
    ToString[TeXForm[s₍ₜ₎[u¹, β]]] -> "\\s_{[t]}"
    };
latexsymbols = {xi, eta, kappa0, kappat, gaussian0, nu, velocity, orig}//Flatten;

GenerateTeX[a_] := StringReplace[ToString[TeXForm[a]],latexsymbols]

# %%
a0 = a[0, E⁽⁰⁾ᵦ /. symbols]
# Out:
# 0

# %%
a1 = a[1, E⁽⁰⁾ᵦ /. symbols]
# Out:
#   1                    2           2       4         2           2         2     2
# -(-) ((2 + 2 𝜈 - 2 𝜂010  - 2 𝜈 𝜂010  + 𝜂010  - 2 𝜉010  - 2 𝜈 𝜉010  + 2 𝜂010  𝜉010  +
#   4
#
#              4        2          2           2    2         2    2      4
# >        𝜉010  - 2 s00  - 2 𝜈 s00  + 2 𝜈 𝜂010  s00  + 2 𝜉010  s00  + s00 ) Y B[s]) /
#
#             2
# >    (-1 + 𝜈 )

# %%
CopyToClipboard[GenerateTeX[a1]]

# %% [markdown]
# $$
# \begin{aligned}
# ={}&-\frac{Y B(s) \left(2 {\nu} {\eta^{(0,1,0)}}^2 {s_{[t]}^{(0,0)}}^2-2 {\nu} {\eta^{(0,1,0)}}^2-2 {\nu} {\xi^{(0,1,0)}}^2-2 {\nu} {s_{[t]}^{(0,0)}}^2+2 {\nu}+{\eta^{(0,1,0)}}^4+2 {\eta^{(0,1,0)}}^2 {\xi^{(0,1,0)}}^2-2 {\eta^{(0,1,0)}}^2+{\xi^{(0,1,0)}}^4+2 {\xi^{(0,1,0)}}^2 {s_{[t]}^{(0,0)}}^2-2 {\xi^{(0,1,0)}}^2+{s_{[t]}^{(0,0)}}^4-2 {s_{[t]}^{(0,0)}}^2+2\right)}{4 \left({\nu}^2-1\right)} \\
# ={}&
# \end{aligned}
# $$

# %%
b1 = a1 /. {𝜉010 -> Sqrt[U], 𝜂010 -> Sqrt[V], s00 -> Sqrt[S]};
c1 = b1*4*(1-𝜈^2)/(Y B[s])//Simplify;
Minimize[{c1, 0≤U, 0≤V, 0≤S, -1<𝜈<1}, {U,V,S}]
# Out:
# {Piecewise[{{0, -1 < 𝜈 < 1}}, Infinity],
#
# >   {U -> Piecewise[{{0, -1 < 𝜈 < 1}}, Indeterminate],
#
# >    V -> Piecewise[{{1, -1 < 𝜈 < 1}}, Indeterminate],
#
# >    S -> Piecewise[{{1, -1 < 𝜈 < 1}}, Indeterminate]}}

# %%
solution1 = {𝜉010 -> 0, 𝜂010 -> 1, s00 -> 1}
# Out:
# {𝜉010 -> 0, 𝜂010 -> 1, s00 -> 1}

# %%
a1 /. solution1
# Out:
# 0

# %%
a1 = a[1, E⁽⁰⁾ᵦ /. symbols /. solution1]
# Out:
# 0

# %%
a2 = a[2, E⁽⁰⁾ᵦ /. symbols /. solution1]
# Out:
# 0

# %%
a3 = a[3, E⁽⁰⁾ᵦ /. symbols /. solution1]
# Out:
#                2         2     2                   2                2     2
# (Y B[s] (6 𝜂011  + 2 𝜂020  B[s]  - (-1 + 𝜈) (3 𝜉011  + (𝜉020 + 𝜂110)  B[s] ) +
#
#                                                            2
# >       4 𝜈 (3 𝜂011 s01 + 𝜂020 (-𝜅00 + 𝜉110 + 𝜅₍₀₎[s]) B[s] ) +
#
#                 2                          2     2            2
# >       2 (3 s01  + (-𝜅00 + 𝜉110 + 𝜅₍₀₎[s])  B[s] ))) / (1 - 𝜈 )

# %%
CopyToClipboard[GenerateTeX[a3]]

# %% [markdown]
# $$
# \frac{Y B(s) \left(4 {\nu} \left({\eta^{(0,2,0)}} B(s)^2 (\kappa_{[0]]}(s)-{\kappa_{[t]}^{(0,0)}}+{\xi^{(1,1,0)}})+3 {\eta^{(0,1,1)}} {s_{[t]}^{(0,1)}}\right)-({\nu}-1) \left(3 {\xi^{(0,1,1)}}^2+({\xi^{(0,2,0)}}+{\eta^{(1,1,0)}})^2 B(s)^2\right)+2 \left(B(s)^2 (\kappa_{[0]]}(s)-{\kappa_{[t]}^{(0,0)}}+{\xi^{(1,1,0)}})^2+3 {s_{[t]}^{(0,1)}}^2\right)+6 {\eta^{(0,1,1)}}^2+2 {\eta^{(0,2,0)}}^2 B(s)^2\right)}{1-{\nu}^2}
# $$

# %%
Minimize[{a3, -1<𝜈<1, B[s]>0, Y>0}, {𝜉110, 𝜉020, 𝜉011, 𝜂110, 𝜂020, 𝜂011, s01, 𝜅00}]
# Out:
# {Piecewise[{{0, B[s] > 0 && Y > 0 && -1 < 𝜈 < 1}}, Infinity],
#
# >   {𝜉110 -> Piecewise[{{0, B[s] > 0 && Y > 0 && -1 < 𝜈 < 1}}, Indeterminate],
#
# >    𝜉020 -> Piecewise[{{0, B[s] > 0 && Y > 0 && -1 < 𝜈 < 1}}, Indeterminate],
#
# >    𝜉011 -> Piecewise[{{0, B[s] > 0 && Y > 0 && -1 < 𝜈 < 1}}, Indeterminate],
#
# >    𝜂110 -> Piecewise[{{0, B[s] > 0 && Y > 0 && -1 < 𝜈 < 1}}, Indeterminate],
#
# >    𝜂020 -> Piecewise[{{0, B[s] > 0 && Y > 0 && -1 < 𝜈 < 1}}, Indeterminate],
#
# >    𝜂011 -> Piecewise[{{0, B[s] > 0 && Y > 0 && -1 < 𝜈 < 1}}, Indeterminate],
#
# >    s01 -> Piecewise[{{0, B[s] > 0 && Y > 0 && -1 < 𝜈 < 1}}, Indeterminate],
#
# >    𝜅00 -> Piecewise[{{𝜅₍₀₎[s], B[s] > 0 && Y > 0 && -1 < 𝜈 < 1}}, Indeterminate]}}

# %%
solution3 = {𝜉110->0, 𝜉020->0, 𝜉011->0, 𝜂110->0, 𝜂020->0, 𝜂011->0, s01->0, 𝜅00->𝜅₍₀₎[s]}
# Out:
# {𝜉110 -> 0, 𝜉020 -> 0, 𝜉011 -> 0, 𝜂110 -> 0, 𝜂020 -> 0, 𝜂011 -> 0, s01 -> 0,
#
# >   𝜅00 -> 𝜅₍₀₎[s]}

# %%
a3/.solution3
# Out:
# 0

# %%
a4 = a[4, E⁽⁰⁾ᵦ /. symbols /. solution1 /. solution3]
# Out:
# 0

# %%
a5 = a[5, E⁽⁰⁾ᵦ /. symbols /. solution1 /. solution3]
# Out:
#                          2           2                     2
# (Y B[s] (15 (-1 + 𝜈) 𝜉012  - 30 (𝜂012  + 2 𝜈 𝜂012 s02 + s02 ) -
#
#                  2         2         2
# >       10 (4 𝜅01  + 4 𝜂021  + 2 𝜉021  + 2 𝜂012 𝜂030 + 𝜉012 𝜉030 +
#
#                                                                   2
# >          2 𝜂111 (2 𝜉021 + 𝜂111) - 𝜈 (𝜉012 𝜉030 + 2 (𝜉021 + 𝜂111) ) + 8 𝜈 𝜂021 𝜉111 +
#
#                  2
# >          4 𝜉111  - 8 𝜅01 (𝜈 𝜂021 + 𝜉111) + 𝜉012 𝜂120 - 𝜈 𝜉012 𝜂120 + 2 𝜈 𝜂012 𝜉120 +
#
#                                                                  2
# >          2 (𝜈 𝜂030 + 𝜉120) s02 + 2 (𝜈 𝜂012 + s02) 𝐾₍₀₎[s]) B[s]  -
#
#                                    2           2                       2
# >       3 (-((-1 + 𝜈) (𝜉030 + 𝜂120) ) + 2 (𝜂030  + 2 𝜈 𝜂030 𝜉120 + 𝜉120 ) +
#
#                                                         4            2
# >          2 𝐾₍₀₎[s] (2 (𝜈 𝜂030 + 𝜉120) + 𝐾₍₀₎[s])) B[s] )) / (-1 + 𝜈 )

# %%
a5 // Simplify
# Out:
#                          2           2                     2
# (Y B[s] (15 (-1 + 𝜈) 𝜉012  - 30 (𝜂012  + 2 𝜈 𝜂012 s02 + s02 ) -
#
#                  2         2         2
# >       10 (4 𝜅01  + 4 𝜂021  + 2 𝜉021  + 2 𝜂012 𝜂030 + 𝜉012 𝜉030 +
#
#                                                                   2
# >          2 𝜂111 (2 𝜉021 + 𝜂111) - 𝜈 (𝜉012 𝜉030 + 2 (𝜉021 + 𝜂111) ) + 8 𝜈 𝜂021 𝜉111 +
#
#                  2
# >          4 𝜉111  - 8 𝜅01 (𝜈 𝜂021 + 𝜉111) + 𝜉012 𝜂120 - 𝜈 𝜉012 𝜂120 + 2 𝜈 𝜂012 𝜉120 +
#
#                                                                  2
# >          2 (𝜈 𝜂030 + 𝜉120) s02 + 2 (𝜈 𝜂012 + s02) 𝐾₍₀₎[s]) B[s]  -
#
#                                    2           2                       2
# >       3 (-((-1 + 𝜈) (𝜉030 + 𝜂120) ) + 2 (𝜂030  + 2 𝜈 𝜂030 𝜉120 + 𝜉120 ) +
#
#                                                         4            2
# >          2 𝐾₍₀₎[s] (2 (𝜈 𝜂030 + 𝜉120) + 𝐾₍₀₎[s])) B[s] )) / (-1 + 𝜈 )

# %%
Minimize[{a5, -1<𝜈<1, B[s]>0, Y>0}, {𝜉120,𝜉012,𝜉030,𝜉021,𝜉111,𝜂111,𝜂012,𝜂030,𝜂021,𝜂120,s02,𝜅01}]
# Out:
# {Piecewise[{{0, B[s] > 0 && Y > 0 && -1 < 𝜈 < 1}}, Infinity],
#
# >   {𝜉120 -> Piecewise[{{-𝐾₍₀₎[s], B[s] > 0 && Y > 0 && -1 < 𝜈 < 1}}, Indeterminate],
#
# >    𝜉012 -> Piecewise[{{0, B[s] > 0 && Y > 0 && -1 < 𝜈 < 1}}, Indeterminate],
#
# >    𝜉030 -> Piecewise[{{0, B[s] > 0 && Y > 0 && -1 < 𝜈 < 1}}, Indeterminate],
#
# >    𝜉021 -> Piecewise[{{0, B[s] > 0 && Y > 0 && -1 < 𝜈 < 1}}, Indeterminate],
#
# >    𝜉111 -> Piecewise[{{0, B[s] > 0 && Y > 0 && -1 < 𝜈 < 1}}, Indeterminate],
#
# >    𝜂111 -> Piecewise[{{0, B[s] > 0 && Y > 0 && -1 < 𝜈 < 1}}, Indeterminate],
#
# >    𝜂012 -> Piecewise[{{0, B[s] > 0 && Y > 0 && -1 < 𝜈 < 1}}, Indeterminate],
#
# >    𝜂030 -> Piecewise[{{0, B[s] > 0 && Y > 0 && -1 < 𝜈 < 1}}, Indeterminate],
#
# >    𝜂021 -> Piecewise[{{0, B[s] > 0 && Y > 0 && -1 < 𝜈 < 1}}, Indeterminate],
#
# >    𝜂120 -> Piecewise[{{0, B[s] > 0 && Y > 0 && -1 < 𝜈 < 1}}, Indeterminate],
#
# >    s02 -> Piecewise[{{0, B[s] > 0 && Y > 0 && -1 < 𝜈 < 1}}, Indeterminate],
#
# ...

# %%
𝜉120,𝜉012,𝜉030,𝜉021,𝜉111,𝜂111,𝜂012,𝜂030,𝜂021,𝜂120,s02,𝜅01

# %%
a5 /.{𝜉120->0,𝜉012->0,𝜉030->0,𝜉021->0,𝜉111->0,𝜂111->0,𝜂012->0,𝜂030->0,𝜂021->0,𝜂120->0,s02->0,𝜅01->0}
# Out:
#             2     5
# -6 Y 𝐾₍₀₎[s]  B[s]
# -------------------
#             2
#       -1 + 𝜈

# %%
solution5 = {𝜉120->-𝐾₍₀₎[s],𝜉012->0,𝜉030->0,𝜉021->0,𝜉111->0,𝜂111->0,𝜂012->0,𝜂030->0,𝜂021->0,𝜂120->0,s02->0,𝜅01->0}
# Out:
# {𝜉120 -> -𝐾₍₀₎[s], 𝜉012 -> 0, 𝜉030 -> 0, 𝜉021 -> 0, 𝜉111 -> 0, 𝜂111 -> 0, 𝜂012 -> 0,
#
# >   𝜂030 -> 0, 𝜂021 -> 0, 𝜂120 -> 0, s02 -> 0, 𝜅01 -> 0}

# %%
a5 /. solution5
# Out:
# 0

# %%
a5 /.{𝜉120->0,𝜉012->0,𝜉030->0,𝜉021->0,𝜉111->0,𝜂111->0,𝜂012->𝜈*𝐾₍₀₎[s]*B[s]^2/3,𝜂030->-𝜈*𝐾₍₀₎[s],𝜂021->0,𝜂120->0,s02->-𝐾₍₀₎[s]*B[s]^2/3,𝜅01->0} //Simplify
# Out:
#            2     5
# 8 Y 𝐾₍₀₎[s]  B[s]
# ------------------
#         3

# %%
E⁽⁰⁾ᵦ /. symbols /. solution1 /. solution3 /. solution5
# Out:
#       3      3        3      3
# {{O[β] , O[β] }, {O[β] , O[β] }}

# %%
Normal[D[W,β]] /. {β->0}
# Out:
#   1                                 2                 2             4
# -(-) (Y B[s] (2 + 2 𝜈 - 2 s₍ₜ₎[s, 0]  - 2 𝜈 s₍ₜ₎[s, 0]  + s₍ₜ₎[s, 0]  -
#   4
#
#             (0,1,0)         2        (0,1,0)         2
# >        2 𝜂       [s, 0, 0]  - 2 𝜈 𝜂       [s, 0, 0]  +
#
#                        2  (0,1,0)         2    (0,1,0)         4
# >        2 𝜈 s₍ₜ₎[s, 0]  𝜂       [s, 0, 0]  + 𝜂       [s, 0, 0]  -
#
#             (0,1,0)         2        (0,1,0)         2
# >        2 𝜉       [s, 0, 0]  - 2 𝜈 𝜉       [s, 0, 0]  +
#
#                      2  (0,1,0)         2      (0,1,0)         2  (0,1,0)         2
# >        2 s₍ₜ₎[s, 0]  𝜉       [s, 0, 0]  + 2 𝜂       [s, 0, 0]  𝜉       [s, 0, 0]  +
#
#           (0,1,0)         4            2
# >        𝜉       [s, 0, 0] )) / (-1 + 𝜈 )

# %%
Normal[D[W,{β,0}]] /. {β->0}
# Out:
# 0

# %%
𝜉₁[u¹_, u²_, β_] = D[𝜉[u¹, u², β], u¹];
𝜉₂[u¹_, u²_, β_] = D[𝜉[u¹, u², β], u²];
𝜂₁[u¹_, u²_, β_] = D[𝜂[u¹, u², β], u¹];
𝜂₂[u¹_, u²_, β_] = D[𝜂[u¹, u², β], u²];

# %%
Normal[𝜉₁[s, β r B[s], β] + O[β]^3] /. symbols /. solution1 /. solution3
# Out:
#                         2     2
#  2                𝜉120 r  B[s]
# β  (𝜉111 r B[s] + -------------)
#                         2

# %%
𝜉[s, β r B[s], β] + O[β]^4 /. symbols /. solution1 /. solution3 /. solution5
𝜉₁[s, β r B[s], β] + O[β]^3 /. symbols /. solution1 /. solution3 /. solution5
𝜉₂[s, β r B[s], β] + O[β]^3 /. symbols /. solution1 /. solution3 /. solution5
# Out:
#     4
# O[β]
#   1    2  2             2        3
# -(-) (r  β  𝐾₍₀₎[s] B[s] ) + O[β]
#   2
#     3
# O[β]

# %%
𝜂[s, β r B[s], β] + O[β]^4 /. symbols /. solution1 /. solution3 /. solution5
𝜂₁[s, β r B[s], β] + O[β]^3 /. symbols /. solution1 /. solution3 /. solution5
𝜂₂[s, β r B[s], β] + O[β]^3 /. symbols /. solution1 /. solution3 /. solution5
# Out:
#                4
# r β B[s] + O[β]
#     3
# O[β]
#         3
# 1 + O[β]

# %%
g₍ₜ₎⁽⁰⁾₁₁[u¹, u², β] + O[β]^3
# Out:
#             2                       (0,1)
# (s₍ₜ₎[u¹, 0]  + 2 β s₍ₜ₎[u¹, 0] s₍ₜ₎     [u¹, 0] +
#
#            (0,1)       2                   (0,2)          2       3
# >     (s₍ₜ₎     [u¹, 0]  + s₍ₜ₎[u¹, 0] s₍ₜ₎     [u¹, 0]) β  + O[β] ) +
#
#                            2
# >   (2 𝜅₍₀₎[u¹] s₍ₜ₎[u¹, β]  + 2 s₍ₜ₎[u¹, β]
#
#                         (0,1,0)               (1,1,0)
# >       (-(𝜅₍ₜ₎[u¹, β] 𝜂       [u¹, 0, β]) + 𝜉       [u¹, 0, β])) u² +
#
#                            2             2
# >   ((𝐾₍₀₎[u¹] + 3 𝜅₍₀₎[u¹] ) s₍ₜ₎[u¹, β]  +
#
#                      (0,1,0)              (1,1,0)           2
# >      (𝜅₍ₜ₎[u¹, β] 𝜉       [u¹, 0, β] + 𝜂       [u¹, 0, β])  +
#
#                                               (0,1,0)               (1,1,0)
# >      4 𝜅₍₀₎[u¹] s₍ₜ₎[u¹, β] (-(𝜅₍ₜ₎[u¹, β] 𝜂       [u¹, 0, β]) + 𝜉       [u¹, 0, β]) +
#
#                        (0,1,0)               (1,1,0)           2
# >      (-(𝜅₍ₜ₎[u¹, β] 𝜂       [u¹, 0, β]) + 𝜉       [u¹, 0, β])  +
#
# ...

# %%
# Out:
#   1    2  2             2        3
# -(-) (r  β  𝐾₍₀₎[s] B[s] ) + O[β]
#   2

# %%
g₍ₜ₎[s, β r B[s], β]
# Out:
#                                    (1,0,0)                 2
# {{(𝜉[s, r β B[s], β] 𝜅₍ₜ₎[s, β] + 𝜂       [s, r β B[s], β])  +
#
#                                                        (1,0,0)                 2
# >     (-(𝜂[s, r β B[s], β] 𝜅₍ₜ₎[s, β]) + s₍ₜ₎[s, β] + 𝜉       [s, r β B[s], β]) ,
#
#       (0,1,0)
# >    𝜂       [s, r β B[s], β] (𝜉[s, r β B[s], β] 𝜅₍ₜ₎[s, β] +
#
#           (1,0,0)
# >        𝜂       [s, r β B[s], β]) +
#
#        (0,1,0)
# >     𝜉       [s, r β B[s], β] (-(𝜂[s, r β B[s], β] 𝜅₍ₜ₎[s, β]) + s₍ₜ₎[s, β] +
#
#           (1,0,0)
# >        𝜉       [s, r β B[s], β])},
#
#       (0,1,0)
# >   {𝜂       [s, r β B[s], β] (𝜉[s, r β B[s], β] 𝜅₍ₜ₎[s, β] +
#
#           (1,0,0)
# >        𝜂       [s, r β B[s], β]) +
#
#        (0,1,0)
# >     𝜉       [s, r β B[s], β] (-(𝜂[s, r β B[s], β] 𝜅₍ₜ₎[s, β]) + s₍ₜ₎[s, β] +
#
#           (1,0,0)
# >        𝜉       [s, r β B[s], β]),
#
#       (0,1,0)                2    (0,1,0)                2
# ...

# %%
Xg₍ₜ₎ = g₍ₜ₎[s, β r B[s], β] /. {
    𝜉₁[s, β r B[s], β] -> Normal[(𝜉₁[s, β r B[s], β] + O[β]^3 /. symbols /. solution1 /. solution3 /. solution5)],
    𝜉₂[s, β r B[s], β] -> Normal[(𝜉₂[s, β r B[s], β] + O[β]^3 /. symbols /. solution1 /. solution3 /. solution5)],
    𝜂₁[s, β r B[s], β] -> Normal[(𝜂₁[s, β r B[s], β] + O[β]^3 /. symbols /. solution1 /. solution3 /. solution5)],
    𝜂₂[s, β r B[s], β] -> Normal[(𝜂₂[s, β r B[s], β] + O[β]^3 /. symbols /. solution1 /. solution3 /. solution5)]
} /. {
    𝜉[s, β r B[s], β] -> Normal[(𝜉[s, β r B[s], β] + O[β]^3 /. symbols /. solution1 /. solution3 /. solution5)],
    𝜂[s, β r B[s], β] -> Normal[(𝜂[s, β r B[s], β] + O[β]^3 /. symbols /. solution1 /. solution3 /. solution5)]
} /. {
    s₍ₜ₎[s, β] -> Normal[s₍ₜ₎[s, β] + O[β]^3 /. symbols /. solution1 /. solution3 /. solution5],
    𝜅₍ₜ₎[s, β] -> Normal[𝜅₍ₜ₎[s, β] + O[β]^2 /. symbols /. solution1 /. solution3 /. solution5]
}
# Out:
#                            2  2             2
#                           r  β  𝐾₍₀₎[s] B[s]  2
# {{(1 - r β 𝜅₍₀₎[s] B[s] - -------------------) , 0}, {0, 1}}
#                                    2

# %%
Xg₍ₜ₎
# Out:
#                            2  2             2
#                           r  β  𝐾₍₀₎[s] B[s]  2
# {{(1 - r β 𝜅₍₀₎[s] B[s] - -------------------) , 0}, {0, 1}}
#                                    2

# %%
Xg₍ₜ₎₁₁ = Xg₍ₜ₎[[1,1]]
Xg₍ₜ₎₁₂ = Xg₍ₜ₎[[1,2]]
Xg₍ₜ₎₂₁ = Xg₍ₜ₎[[2,1]]
Xg₍ₜ₎₂₂ = Xg₍ₜ₎[[2,2]]
# Out:
#                          2  2             2
#                         r  β  𝐾₍₀₎[s] B[s]  2
# (1 - r β 𝜅₍₀₎[s] B[s] - -------------------)
#                                  2
# 0
# 0
# 1

# %%
Xg₍₀₎₁₁ = Normal[g₍₀₎₁₁[u¹, u²]] /. {u¹->s, u²->β r B[s]}
# Out:
#                           2  2                    2      2
# 1 - 2 r β 𝜅₍₀₎[s] B[s] + r  β  (-𝐾₍₀₎[s] + 𝜅₍₀₎[s] ) B[s]

# %%
Xg₍ₜ₎⁽⁰⁾₁₁ = Xg₍ₜ₎₁₁ / Xg₍₀₎₁₁;
Xg₍ₜ₎⁽⁰⁾₁₂ = Xg₍ₜ₎₁₂ / Sqrt[Xg₍₀₎₁₁];
Xg₍ₜ₎⁽⁰⁾₂₁ = Xg₍ₜ₎₂₁ / Sqrt[Xg₍₀₎₁₁];
Xg₍ₜ₎⁽⁰⁾₂₂ = Xg₍ₜ₎₂₂;
Xg₍ₜ₎⁽⁰⁾ = {{Xg₍ₜ₎⁽⁰⁾₁₁,Xg₍ₜ₎⁽⁰⁾₁₂},{Xg₍ₜ₎⁽⁰⁾₂₁,Xg₍ₜ₎⁽⁰⁾₂₂}};

# %%
Xg₍ₜ₎⁽⁰⁾ + O[β]^3
# Out:
#           3      3        3          3
# {{1 + O[β] , O[β] }, {O[β] , 1 + O[β] }}

# %%
s₍ₜ₎[𝜏, β]𝒆₁[𝜏, β];
Derivative[1,0][𝒆₁][𝜏_, β_] = 𝜅₍ₜ₎[𝜏, β]𝒆₂[𝜏,

# %%
D[𝜉₁[u¹_, u²_, β_]
# Out:
# 𝜉

# %%
𝒑₍ₜ₎₁[u¹, u², β]
# Out:
# -(𝜂[u¹, u², β] 𝒆₁[u¹, β] 𝜅₍ₜ₎[u¹, β]) + 𝜉[u¹, u², β] 𝒆₂[u¹, β] 𝜅₍ₜ₎[u¹, β] +
#
#                                        (1,0,0)                         (1,0,0)
# >   𝒆₁[u¹, β] s₍ₜ₎[u¹, β] + 𝒆₂[u¹, β] 𝜂       [u¹, u², β] + 𝒆₁[u¹, β] 𝜉       [u¹, u², β]

# %%
𝒑₍ₜ₎₁[u¹_, u²_, β_] = D[𝒑₍ₜ₎[u¹, u², β], u¹];
𝒑₍ₜ₎₂[u¹_, u²_, β_] = D[𝒑₍ₜ₎[u¹, u², β], u²];

# %%
a[m_,E⁽⁰⁾ᵦ_]

# %%
symbols={
    (* For Energy Minimization *)
    Derivative[i_,j_,k_][𝜉][s,0,0] :> Symbol["𝜉"<>ToString[i]<>ToString[j]<>ToString[k]],
    Derivative[i_,j_,k_][𝜂][s,0,0] :> Symbol["𝜂"<>ToString[i]<>ToString[j]<>ToString[k]],
    Derivative[i_,j_][𝜅₍ₜ₎][s,0] :> Symbol["𝜅"<>ToString[i]<>ToString[j]],
    Derivative[i_,j_][s₍ₜ₎][s,0] :> Symbol["s"<>ToString[i]<>ToString[j]],
    𝜅₍ₜ₎[s,0] :> 𝜅00,
    s₍ₜ₎[s,0] :> s00
};

# %% [markdown]
# $$
# W(\beta)
# = \int_M \mathcal{W}
# = \int_I \int_{-B(u^1)}^{B(u^2)} \mathcal{W_\beta} du^2 du^1
# = \int_I \int_{-1}^{1} \mathcal{W_\beta}\beta B(s) dr ds
# $$

# %%
E⁽⁰⁾ᵦ /. symbols
# Out:
#            2
#   (-1 + s00 )
# {{----------- + s00 β (s01 + (-(𝜅00 𝜂010) + 𝜉110) r B[s] + r s00 𝜅₍₀₎[s] B[s]) +
#        2
#
#         2     2
# >     (β  (s01  + s00 s02 + 2 r ((-(𝜅01 𝜂010) - 𝜅00 𝜂011 + 𝜉111) s00 +
#
# >             (-(𝜅00 𝜂010) + 𝜉110) s01 + 2 s00 s01 𝜅₍₀₎[s]) B[s] +
#
#             2                   2                       2
# >          r  ((𝜅00 𝜉010 + 𝜂110)  + (-(𝜅00 𝜂010) + 𝜉110)  + (-(𝜅00 𝜂020) + 𝜉120) s00 +
#
#                                                       2                     2       2
# >             4 (-(𝜅00 𝜂010) + 𝜉110) s00 𝜅₍₀₎[s] + s00  (𝐾₍₀₎[s] + 3 𝜅₍₀₎[s] )) B[s] ))\
#
#                   3  𝜉010 s00
# >       / 2 + O[β] , -------- + (β (𝜉011 s00 + 𝜉010 s01 +
#                         2
#
# >          r (𝜂010 𝜂110 + 𝜉010 𝜉110 + 𝜉020 s00 + 𝜉010 s00 𝜅₍₀₎[s]) B[s])) / 2 +
#
#         2  𝜉012 s00 + 2 𝜉011 s01 + 𝜉010 s02
# >     (β  (-------------------------------- +
#                           2
#
# ...

# %%
E⁽⁰⁾ᵦ /. symbols /. trivials
# Out:
#            2
#   (-1 + s00 )
# {{----------- + s00 β (s01 + (-(𝜅00 𝜂010) + 𝜉110) r B[s] + r s00 𝜅₍₀₎[s] B[s]) +
#        2
#
#         2     2
# >     (β  (s01  + s00 s02 + 2 r ((-(𝜅01 𝜂010) - 𝜅00 𝜂011 + 𝜉111) s00 +
#
# >             (-(𝜅00 𝜂010) + 𝜉110) s01 + 2 s00 s01 𝜅₍₀₎[s]) B[s] +
#
#             2                   2                       2
# >          r  ((𝜅00 𝜉010 + 𝜂110)  + (-(𝜅00 𝜂010) + 𝜉110)  + (-(𝜅00 𝜂020) + 𝜉120) s00 +
#
#                                                       2                     2       2
# >             4 (-(𝜅00 𝜂010) + 𝜉110) s00 𝜅₍₀₎[s] + s00  (𝐾₍₀₎[s] + 3 𝜅₍₀₎[s] )) B[s] ))\
#
#                   3  𝜉010 s00
# >       / 2 + O[β] , -------- + (β (𝜉011 s00 + 𝜉010 s01 +
#                         2
#
# >          r (𝜂010 𝜂110 + 𝜉010 𝜉110 + 𝜉020 s00 + 𝜉010 s00 𝜅₍₀₎[s]) B[s])) / 2 +
#
#         2  𝜉012 s00 + 2 𝜉011 s01 + 𝜉010 s02
# >     (β  (-------------------------------- +
#                           2
#
# ...

# %%
trivials = {𝜉000->0, 𝜉100->0, 𝜉001->0, 𝜉200->0, 𝜉101->0, 𝜉002->0, 𝜉300->0, 𝜉201->0, 𝜉102->0, 𝜉003->0,
            𝜂000->0, 𝜂100->0, 𝜂001->0, 𝜂200->0, 𝜂101->0, 𝜂002->0, 𝜂300->0, 𝜂201->0, 𝜂102->0, 𝜂003->0};

# %%
E⁽⁰⁾ᵦ /. symbols
# Out:
#            2
#   (-1 + s00 )
# {{----------- + s00 β (s01 + (-(𝜅00 𝜂010) + 𝜉110) r B[s] + r s00 𝜅₍₀₎[s] B[s]) +
#        2
#
#         2     2
# >     (β  (s01  + s00 s02 + 2 r ((-(𝜅01 𝜂010) - 𝜅00 𝜂011 + 𝜉111) s00 +
#
# >             (-(𝜅00 𝜂010) + 𝜉110) s01 + 2 s00 s01 𝜅₍₀₎[s]) B[s] +
#
#             2                   2                       2
# >          r  ((𝜅00 𝜉010 + 𝜂110)  + (-(𝜅00 𝜂010) + 𝜉110)  + (-(𝜅00 𝜂020) + 𝜉120) s00 +
#
#                                                       2                     2       2
# >             4 (-(𝜅00 𝜂010) + 𝜉110) s00 𝜅₍₀₎[s] + s00  (𝐾₍₀₎[s] + 3 𝜅₍₀₎[s] )) B[s] ))\
#
#                   3  𝜉010 s00
# >       / 2 + O[β] , -------- + (β (𝜉011 s00 + 𝜉010 s01 +
#                         2
#
# >          r (𝜂010 𝜂110 + 𝜉010 𝜉110 + 𝜉020 s00 + 𝜉010 s00 𝜅₍₀₎[s]) B[s])) / 2 +
#
#         2  𝜉012 s00 + 2 𝜉011 s01 + 𝜉010 s02
# >     (β  (-------------------------------- +
#                           2
#
# ...

# %%
{𝜉010->0, 𝜂010->1, s00->1}

# %%
E⁽⁰⁾ᵦ /. symbols;

# %%
{𝜉010->0, 𝜂010->1, s00->1}
# Out:
# {𝜉010 -> 0, 𝜂010 -> 1, s00 -> 1}

# %%
𝒲ᵦ[E⁽⁰⁾ᵦ /. symbols]*β*B[s] + O[β]^2
# Out:
#       2    2                 2       2           2
#   𝜉010  s00  Y   𝜈 (-1 + 𝜂010  + 𝜉010 ) (-1 + s00 ) Y
# ((------------ + ------------------------------------ +
#    2 (1 + 𝜈)              2 (1 - 𝜈) (1 + 𝜈)
#
#                    2       2 2    Y           𝜈 Y
#          (-1 + 𝜂010  + 𝜉010 )  (----- + ---------------)
#                                 1 + 𝜈   (1 - 𝜈) (1 + 𝜈)
# >        ----------------------------------------------- +
#                                 4
#
#                   2 2    Y           𝜈 Y
#          (-1 + s00 )  (----- + ---------------)
#                        1 + 𝜈   (1 - 𝜈) (1 + 𝜈)                     2
# >        --------------------------------------) β B[s]) / 2 + O[β]
#                            4

# %%
𝒲ᵦ[E⁽⁰⁾ᵦ /. symbols /. {𝜉010->0, 𝜂010->1, s00->1}]*β*B[s] + O[β]^2
# Out:
#     2
# O[β]

# %%
𝒲ᵦ[E⁽⁰⁾ᵦ /. symbols /. {𝜉010->0, 𝜂010->1, s00->1}]*β*B[s] + O[β]^3
# Out:
#     3
# O[β]

# %%
𝒲ᵦ[E⁽⁰⁾ᵦ /. symbols /. {𝜉010->0, 𝜂010->1, s00->1}]*β*B[s] + O[β]^4
# Out:
#   3          Y           𝜈 Y                            2
# (β  B[s] ((----- + ---------------) (𝜂011 + 𝜂020 r B[s])  +
#            1 + 𝜈   (1 - 𝜈) (1 + 𝜈)
#
#                                         2
#          Y (𝜉011 + (𝜉020 + 𝜂110) r B[s])
# >        -------------------------------- +
#                     2 (1 + 𝜈)
#
#          2 𝜈 Y (𝜂011 + 𝜂020 r B[s]) (s01 + (-𝜅00 + 𝜉110) r B[s] + r 𝜅₍₀₎[s] B[s])
# >        ------------------------------------------------------------------------ +
#                                      (1 - 𝜈) (1 + 𝜈)
#
#             Y           𝜈 Y                                                     2
# >        (----- + ---------------) (s01 + (-𝜅00 + 𝜉110) r B[s] + r 𝜅₍₀₎[s] B[s]) )) / 2\
#           1 + 𝜈   (1 - 𝜈) (1 + 𝜈)
#
#            4
# >    + O[β]

# %%
iint = 𝒲ᵦ*β*B[s];

# %%
iint+O[β]
# Out:
# O[β]

# %%
Integrate[Normal[iint+O[β]^2], {r,-1,1}] /. symbols
# Out:
#      2    2                 2       2           2
#  𝜉010  s00  Y   𝜈 (-1 + 𝜂010  + 𝜉010 ) (-1 + s00 ) Y
# (------------ + ------------------------------------ +
#   2 (1 + 𝜈)              2 (1 - 𝜈) (1 + 𝜈)
#
#                 2       2 2    Y           𝜈 Y
#       (-1 + 𝜂010  + 𝜉010 )  (----- + ---------------)
#                              1 + 𝜈   (1 - 𝜈) (1 + 𝜈)
# >     ----------------------------------------------- +
#                              4
#
#                2 2    Y           𝜈 Y
#       (-1 + s00 )  (----- + ---------------)
#                     1 + 𝜈   (1 - 𝜈) (1 + 𝜈)
# >     --------------------------------------) β B[s]
#                         4

# %%
iint = Normal[𝒲ᵦ]*β*B[s];

# %%
in = Integrate[Normal[iint], {r,-1,1}]
# Out:
#                            2               4                       (0,1)
# (Y β B[s] (4 - 8 s₍ₜ₎[s, 0]  + 4 s₍ₜ₎[s, 0]  - 16 β s₍ₜ₎[s, 0] s₍ₜ₎     [s, 0] -
#
#                               (0,1)                        3     (0,1)
# >       16 𝜈 β s₍ₜ₎[s, 0] s₍ₜ₎     [s, 0] + 16 β s₍ₜ₎[s, 0]  s₍ₜ₎     [s, 0] +
#
#                               (0,1)        (0,1,0)         2
# >       16 𝜈 β s₍ₜ₎[s, 0] s₍ₜ₎     [s, 0] 𝜂       [s, 0, 0]  -
#
#                              2  (0,1,0)         2
# >       8 (-1 + 𝜈) s₍ₜ₎[s, 0]  𝜉       [s, 0, 0]  +
#
#                             (0,1)        (0,1,0)         2
# >       16 β s₍ₜ₎[s, 0] s₍ₜ₎     [s, 0] 𝜉       [s, 0, 0]  +
#
#                             2         (0,1,0)         2    (0,1,0)         2
# >       8 𝜈 (-1 + s₍ₜ₎[s, 0] ) (-1 + 𝜂       [s, 0, 0]  + 𝜉       [s, 0, 0] ) +
#
#                  (0,1,0)         2    (0,1,0)         2 2
# >       4 (-1 + 𝜂       [s, 0, 0]  + 𝜉       [s, 0, 0] )  -
#
# ...

# %%
iint+O[β]^4
# Out:
#             Y           𝜈 Y                        2 2
#          (----- + ---------------) (-1 + s₍ₜ₎[s, 0] )
#           1 + 𝜈   (1 - 𝜈) (1 + 𝜈)
# (β B[s] (--------------------------------------------- +
#                                4
#
#                      2  (0,1,0)         2
#          Y s₍ₜ₎[s, 0]  𝜉       [s, 0, 0]
# >        -------------------------------- +
#                     2 (1 + 𝜈)
#
#                              2         (0,1,0)         2    (0,1,0)         2
#          𝜈 Y (-1 + s₍ₜ₎[s, 0] ) (-1 + 𝜂       [s, 0, 0]  + 𝜉       [s, 0, 0] )
# >        --------------------------------------------------------------------- +
#                                    2 (1 - 𝜈) (1 + 𝜈)
#
#             Y           𝜈 Y               (0,1,0)         2    (0,1,0)         2 2
#          (----- + ---------------) (-1 + 𝜂       [s, 0, 0]  + 𝜉       [s, 0, 0] )
#           1 + 𝜈   (1 - 𝜈) (1 + 𝜈)
# ...

# %%
in+O[β]^4
# Out:
#                            2               4
# (Y β B[s] (4 - 8 s₍ₜ₎[s, 0]  + 4 s₍ₜ₎[s, 0]  -
#
#                               2  (0,1,0)         2
# >        8 (-1 + 𝜈) s₍ₜ₎[s, 0]  𝜉       [s, 0, 0]  +
#
#                              2         (0,1,0)         2    (0,1,0)         2
# >        8 𝜈 (-1 + s₍ₜ₎[s, 0] ) (-1 + 𝜂       [s, 0, 0]  + 𝜉       [s, 0, 0] ) +
#
#                   (0,1,0)         2    (0,1,0)         2 2               2
# >        4 (-1 + 𝜂       [s, 0, 0]  + 𝜉       [s, 0, 0] ) )) / (16 (1 - 𝜈 )) -
#
#         2                        (0,1)                           (0,1)
# >   (Y β  B[s] (-(s₍ₜ₎[s, 0] s₍ₜ₎     [s, 0]) - 𝜈 s₍ₜ₎[s, 0] s₍ₜ₎     [s, 0] +
#
#                    3     (0,1)                          (0,1)        (0,1,0)         2
# >        s₍ₜ₎[s, 0]  s₍ₜ₎     [s, 0] + 𝜈 s₍ₜ₎[s, 0] s₍ₜ₎     [s, 0] 𝜂       [s, 0, 0]  +
#
#                         (0,1)        (0,1,0)         2
# >        s₍ₜ₎[s, 0] s₍ₜ₎     [s, 0] 𝜉       [s, 0, 0]  -
#
# ...

# %%
iint = Normal[𝒲ᵦ]*β*B[s];

# %%
iint+O[β]
# Out:
# O[β]

# %%
iint+O[β]^2
# Out:
#             Y           𝜈 Y                        2 2
#          (----- + ---------------) (-1 + s₍ₜ₎[s, 0] )
#           1 + 𝜈   (1 - 𝜈) (1 + 𝜈)
# (β B[s] (--------------------------------------------- +
#                                4
#
#                      2  (0,1,0)         2
#          Y s₍ₜ₎[s, 0]  𝜉       [s, 0, 0]
# >        -------------------------------- +
#                     2 (1 + 𝜈)
#
#                              2         (0,1,0)         2    (0,1,0)         2
#          𝜈 Y (-1 + s₍ₜ₎[s, 0] ) (-1 + 𝜂       [s, 0, 0]  + 𝜉       [s, 0, 0] )
# >        --------------------------------------------------------------------- +
#                                    2 (1 - 𝜈) (1 + 𝜈)
#
#             Y           𝜈 Y               (0,1,0)         2    (0,1,0)         2 2
#          (----- + ---------------) (-1 + 𝜂       [s, 0, 0]  + 𝜉       [s, 0, 0] )
#           1 + 𝜈   (1 - 𝜈) (1 + 𝜈)
# ...

# %%
ki = Normal[iint+O[β]^2] // Simplify
# Out:
#   1                                 4    (0,1,0)         4      (0,1,0)         2
# -(-) (Y β B[s] (2 + 2 𝜈 + s₍ₜ₎[s, 0]  + 𝜂       [s, 0, 0]  - 2 𝜉       [s, 0, 0]  -
#   8
#
#               (0,1,0)         2    (0,1,0)         4
# >        2 𝜈 𝜉       [s, 0, 0]  + 𝜉       [s, 0, 0]  -
#
#             (0,1,0)         2           (0,1,0)         2
# >        2 𝜂       [s, 0, 0]  (1 + 𝜈 - 𝜉       [s, 0, 0] ) +
#
#                      2              (0,1,0)         2    (0,1,0)         2             2
# >        2 s₍ₜ₎[s, 0]  (-1 - 𝜈 + 𝜈 𝜂       [s, 0, 0]  + 𝜉       [s, 0, 0] ))) / (-1 + 𝜈 )

# %%
ae = Integrate[Normal[ki], {r,-1,1}] // Simplify
# Out:
#   1                                 4    (0,1,0)         4      (0,1,0)         2
# -(-) (Y β B[s] (2 + 2 𝜈 + s₍ₜ₎[s, 0]  + 𝜂       [s, 0, 0]  - 2 𝜉       [s, 0, 0]  -
#   4
#
#               (0,1,0)         2    (0,1,0)         4
# >        2 𝜈 𝜉       [s, 0, 0]  + 𝜉       [s, 0, 0]  -
#
#             (0,1,0)         2           (0,1,0)         2
# >        2 𝜂       [s, 0, 0]  (1 + 𝜈 - 𝜉       [s, 0, 0] ) +
#
#                      2              (0,1,0)         2    (0,1,0)         2             2
# >        2 s₍ₜ₎[s, 0]  (-1 - 𝜈 + 𝜈 𝜂       [s, 0, 0]  + 𝜉       [s, 0, 0] ))) / (-1 + 𝜈 )

# %%
(ae /.symbols)
# Out:
#   1                  4         2           2       4         2              2
# -(-) ((2 + 2 𝜈 + 𝜂010  - 2 𝜉010  - 2 𝜈 𝜉010  + 𝜉010  - 2 𝜂010  (1 + 𝜈 - 𝜉010 ) +
#   4
#
#                            2       2     2      4                     2
# >        2 (-1 - 𝜈 + 𝜈 𝜂010  + 𝜉010 ) s00  + s00 ) Y β B[s]) / (-1 + 𝜈 )

# %%
(ae /.symbols) /. {𝜉010->0, 𝜂010->1, s00->1} //Simplify
# Out:
# 0

# %%
(in /.symbols) /. {𝜉010->0, 𝜂010->1, s00->1} //Simplify
# Out:
#   1      3              2         2     2                   2                2     2
# -(-) (Y β  B[s] (-6 𝜂011  - 2 𝜂020  B[s]  + (-1 + 𝜈) (3 𝜉011  + (𝜉020 + 𝜂110)  B[s] ) -
#   6
#
#                                                             2
# >        4 𝜈 (3 𝜂011 s01 + 𝜂020 (-𝜅00 + 𝜉110 + 𝜅₍₀₎[s]) B[s] ) -
#
#                  2                          2     2            2
# >        2 (3 s01  + (-𝜅00 + 𝜉110 + 𝜅₍₀₎[s])  B[s] ))) / (1 - 𝜈 )

# %%
fae = (in /.symbols) /. {𝜉010->0, 𝜂010->1, s00->1} //Simplify
# Out:
#   1      3              2         2     2                   2                2     2
# -(-) (Y β  B[s] (-6 𝜂011  - 2 𝜂020  B[s]  + (-1 + 𝜈) (3 𝜉011  + (𝜉020 + 𝜂110)  B[s] ) -
#   6
#
#                                                             2
# >        4 𝜈 (3 𝜂011 s01 + 𝜂020 (-𝜅00 + 𝜉110 + 𝜅₍₀₎[s]) B[s] ) -
#
#                  2                          2     2            2
# >        2 (3 s01  + (-𝜅00 + 𝜉110 + 𝜅₍₀₎[s])  B[s] ))) / (1 - 𝜈 )

# %%
fae + O[β]^4
# Out:
#   1      3              2         2     2                   2                2     2
# -(-) (Y β  B[s] (-6 𝜂011  - 2 𝜂020  B[s]  + (-1 + 𝜈) (3 𝜉011  + (𝜉020 + 𝜂110)  B[s] ) -
#   6
#
#                                                              2
# >         4 𝜈 (3 𝜂011 s01 + 𝜂020 (-𝜅00 + 𝜉110 + 𝜅₍₀₎[s]) B[s] ) -
#
#                   2                          2     2            2        4
# >         2 (3 s01  + (-𝜅00 + 𝜉110 + 𝜅₍₀₎[s])  B[s] ))) / (1 - 𝜈 ) + O[β]

# %%
Integrate[𝒲ᵦ,{r,-1,1}]
# Out:
#      2             2             2            2              2
# (Y (β  𝐾₍₀₎[s] B[s]  (2 g₍ₜ₎⁽⁰⁾₁₁  + g₍ₜ₎⁽⁰⁾₁₂  - 𝜈 g₍ₜ₎⁽⁰⁾₁₂  + 2 g₍ₜ₎⁽⁰⁾₁₂ g₍ₜ₎⁽⁰⁾₂₁ -
#
#                                               2              2
# >          2 𝜈 g₍ₜ₎⁽⁰⁾₁₂ g₍ₜ₎⁽⁰⁾₂₁ + g₍ₜ₎⁽⁰⁾₂₁  - 𝜈 g₍ₜ₎⁽⁰⁾₂₁  +
#
#                                                 2               4
# >          4 𝜈 g₍ₜ₎⁽⁰⁾₁₁ g₍ₜ₎⁽⁰⁾₂₂ + 2 g₍ₜ₎⁽⁰⁾₂₂  - 6 s₍ₜ₎[s, 0]  +
#
#               (0,1,0)         4                  (0,1,0)         2
# >          2 𝜂       [s, 0, 0]  - 4 𝜈 g₍ₜ₎⁽⁰⁾₁₁ 𝜉       [s, 0, 0]  -
#
#                         (0,1,0)         2      (0,1,0)         4
# >          4 g₍ₜ₎⁽⁰⁾₂₂ 𝜉       [s, 0, 0]  + 2 𝜉       [s, 0, 0]  -
#
#               (0,1,0)         2                             (0,1,0)         2
# >          4 𝜂       [s, 0, 0]  (𝜈 g₍ₜ₎⁽⁰⁾₁₁ + g₍ₜ₎⁽⁰⁾₂₂ - 𝜉       [s, 0, 0] ) +
#
#                        2                               (0,1,0)         2
# ...

# %%
g₍₀₎₁₁ᵦ = (Normal[g₍₀₎₁₁[u¹, u²]] /. {u¹->s, u²->r B[s] β}) + O[β]^3;
g₍₀₎₁₂ᵦ = 0;
g₍₀₎₂₁ᵦ = 0;
g₍₀₎₂₂ᵦ = 1;

# %%
(Normal[g₍₀₎₁₁[u¹, u²]] /. {u¹->s, u²->r B[s] β}) + O[β]^3
# Out:
#                           2  2                    2      2       3
# 1 - 2 r β 𝜅₍₀₎[s] B[s] + r  β  (-𝐾₍₀₎[s] + 𝜅₍₀₎[s] ) B[s]  + O[β]
